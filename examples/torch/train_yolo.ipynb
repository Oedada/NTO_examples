# %%
from ultralytics.data.converter import convert_coco

convert_coco(
    labels_dir="/home/oedada/Projects/experiments/NTO/Final/tracking/data/parking/test/", # директория в которой лежит json 
    save_dir="/home/oedada/Projects/experiments/NTO/Final/tracking/data/parking/test/anno" # директория в которой будут txt файлы(без картинок)
)   
convert_coco(
    labels_dir="/home/oedada/Projects/experiments/NTO/Final/tracking/data/parking/train/",
    save_dir="/home/oedada/Projects/experiments/NTO/Final/tracking/data/parking/train/anno"
)
convert_coco(
    labels_dir="/home/oedada/Projects/experiments/NTO/Final/tracking/data/parking/valid/",
    save_dir="/home/oedada/Projects/experiments/NTO/Final/tracking/data/parking/train/valid"
)
# Out:
# Annotations /home/oedada/Projects/experiments/NTO/Final/tracking/data/parking/test/_annotations.coco.json: 100% ━━━━━━━━━━━━ 1216/1216 1.3Kit/s 0.9s0.0s
# COCO data converted successfully.
# Results saved to /home/oedada/Projects/experiments/NTO/Final/tracking/data/parking/test/anno

# %%
from ultralytics import YOLO

model = YOLO("yolov5n.pt")

model.info()

results = model.train(
    data="data/anno.yaml", # пример yaml файла для yolo
    epochs=100,
    imgsz=640,
    save_period=1, # раз во сколько эпох сохранять модел в runs/weights
    project="/home/oedada/Projects/experiments/NTO/Final/runs", # чтобы сохранение работало
    name="parking_yolo" # чтобы сохранение работало
)
# Out:
# PRO TIP 💡 Replace 'model=yolov5n.pt' with new 'model=yolov5nu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# YOLOv5n summary: 153 layers, 2,654,816 parameters, 0 gradients, 7.8 GFLOPs
# Ultralytics 8.4.14 🚀 Python-3.12.11 torch-2.10.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3050, 7833MiB)
# ...
